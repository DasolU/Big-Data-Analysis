# %% [markdown]
# # Boosting이 우승하는 이유?
# DS에서는 딥러닝이 쓰이지 않고 Tree 모델이 쓰인다.
#
# ![image.png](attachment:image.png)
#
# ## 딥러닝 쓰지 않는 이유?
# 1. graphical feature가 존재하지 않기 때문에
# 2. 학습 원리: Tree이기 때문에
#     - 예) 게임유저 이탈 예측 문제 (이탈/비이탈)
# 3. feature들이 연속성이 없기 때문에
