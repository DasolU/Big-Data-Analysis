# %% [markdown]
# # LDA 장단점
#
# ![image.png](attachment:image.png)
#
#
# - 장점 추가 설명:
#     - Navie Bayes 모델은 **조건부 독립을 가정**
#         - LDA는 공분산 구조 반영
#     - 2. 정규분포 가정에 위배되더라도 비교적 robust(변화에 민감하지 않다)

# %% [markdown]
# # QDA (quadratic)
# ## 필요성
# y 범주별로 공분산 구조가 다를 경우 사용 가능
#
# ![image.png](attachment:image.png)
#
# ## 상대적 장단점
# ![image-2.png](attachment:image-2.png)
