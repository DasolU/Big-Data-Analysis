# %% [markdown]
# # 행렬식 계산 방법
# - Cramar's Rule
#     - 0이 많은 행 또는 열 선택
#     ![image.png](attachment:image.png)
#
# # 행렬식의 기하학적 의미
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 행렬식 활용
# - 역행렬이 존재하는가 여부 판단에 사용
# ![image.png](attachment:image.png)
