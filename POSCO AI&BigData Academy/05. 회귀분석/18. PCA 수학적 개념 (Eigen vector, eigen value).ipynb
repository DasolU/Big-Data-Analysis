# %% [markdown]
# # Eigen vector, eigen value
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Eigen vector, eigen value 계산
# - 역행렬이 존재하지 않아야 Eigen vector가 존재한다.
#     - 행렬식이 0이어야 역행렬이 존재하지 않는다.
