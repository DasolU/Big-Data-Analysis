# %% [markdown]
# # PCA 수행과정
# 1. Mean centering
# 2. SVD 수행
# 3. SVD 결과를 활용하여 공분산의 eigen vector, eigen value 구하기
# 4. PC score 구하기
# ![image.png](attachment:image.png)
# 5. PC score를 활용하여 분석 진행
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # PCA의 심화적 이해
# ## PC score의 기하학적 해석
# - 관측치와 eigen vector와의 내적값
# - 즉, 데이터를 가장 잘 설명하는 축에 대한 데이터의 좌표
# ![image.png](attachment:image.png)
