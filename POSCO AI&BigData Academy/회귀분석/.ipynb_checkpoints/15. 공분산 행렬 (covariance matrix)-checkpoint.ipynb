# %% [markdown]
# # 공분산 행렬 (covariance matrix)
# - 정의
# ![image.png](attachment:image.png)
#
# - 점과 공분산의 내적 연산: 점의 위치를 타원 형태로 이동시킨다.
# ![image-2.png](attachment:image-2.png)
#
# - 기하학적 의미 참고
#     - 공분산 값이 음수인 경우: 점의 위치가 바뀐다.
#         - (positive definite)
#     - 행렬식이 0인 경우: 점의 위치가 선분(한 줄)로 바뀐다.
