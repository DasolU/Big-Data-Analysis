# %% [markdown]
# # Projection
# - 목표: 분산 최소, 평균 최대화 하는 사영 찾는 것
# ![image.png](attachment:image.png)

# %% [markdown]
# # 사영과 eigen value, eigen vector와의 연관성
# - B: 두 평균의 차이
# - W: 각 평균에 대한 분산의 합
# - A: 사영을 통해 찾아낸 새로운 축 = decision boundary 평면의 법선 벡터 = eigen vector
# ![image.png](attachment:image.png)

# %% [markdown]
# # 총정리
# ![image.png](attachment:image.png)
